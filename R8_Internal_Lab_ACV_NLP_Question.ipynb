# %% [markdown]
# # CV and Transfer Learning

# %% [markdown]
# Q1. Import tensorflow (2.x Mandatory)
#
# *   Import other required libraries

# %%
% tensorflow_version 2.x
import tensorflow as tf
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# Q2. Load CIFAR10 dataset from keras and split into train and test
# *    Identify shape of x_train and y_train

# %%
#Load CIFAR10 dataset available within tensorflow
(train_x, train_y),(test_x,test_y) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 13s 0us/step

# %%
print ('Shape of train_x :', train_x.shape)
print ('Shape of test_x :', test_x.shape)
print ('Shape of train_x :', train_y.shape)
print ('Shape of test_x :', test_y.shape)
# Out:
# Shape of train_x : (50000, 32, 32, 3)
# Shape of test_x : (10000, 32, 32, 3)
# Shape of train_x : (50000, 1)
# Shape of test_x : (10000, 1)

# %% [markdown]
# Q3.
#
# *   Transform x_train and x_test on scale of 0-1
# *   Transform y_train and y_test to categories

# %%
# to normalize train_x and test_x
x_train = train_x/255
x_test = test_x/255

# %%
#Convert labels to one hot encoding
y_train = tf.keras.utils.to_categorical(train_y, num_classes=10)
y_test = tf.keras.utils.to_categorical(test_y, num_classes=10)

# %%
#Let's review the data
import numpy as np
import matplotlib.pyplot as plt
img_num = np.random.randint(0, test_x.shape[0]) #Get a random integer between 0 and number of examples in test dataset
plt.imshow(test_x[img_num],cmap='gray') #Show the image from test dataset
plt.suptitle('Number: ' + str(y_test[img_num]))
plt.show()

# %% [markdown]
# Q4. Import necessary packages required for Model building
# *   Conv2D, Dense, Flatten, Dropout, MaxPooling2D etc.

# %%
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout,Activation
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.backend import clear_session
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#Clear out tensorflow memory
tf.keras.backend.clear_session()

# %% [markdown]
# Q5. Prepare a CNN
#
# *   Which will include above layers
# *   Freely create your own Architecture and Arguments
# *   Print Model Summary

# %%
# Sequential
model = Sequential()

# 1st CNN layer
model.add(Conv2D(32, (3, 3), padding='same',input_shape=x_train.shape[1:]))
model.add(Activation('relu'))

# 2nd CNN layer 
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))

# Max pool layer 
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25)) # dropout = 25%

# third CNN layer 
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))

# 4th CNN layer 
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))

# max pool  2
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25)) # Dropout = 25%

# Flattening the layer 
model.add(Flatten())

# Dens layer 
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5)) # drpout

# Output layer 
model.add(Dense(10))
model.add(Activation('softmax'))

# %%
#Specify Loass and Optimizer
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1180160
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_5 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Q6. Train the CNN
#
# *   Compile the model
# *   Fit the model (10 epochs, 32 batch size)
# *   Evaluate Model Performance

# %%
mckpt = tf.keras.callbacks.ModelCheckpoint('./cifar.h5', 
                                           monitor='val_acc', save_best_only=True)

# %%
model.fit(x_train,y_train,          
          validation_data=(x_test,y_test),
          epochs=5,
          batch_size=32, callbacks=[mckpt],workers=4)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.4833 - accuracy: 0.4624WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 17s 347us/sample - loss: 1.4826 - accuracy: 0.4628 - val_loss: 1.1453 - val_accuracy: 0.5872
# Epoch 2/5
# 49824/50000 [============================>.] - ETA: 0s - loss: 1.0891 - accuracy: 0.6140WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 1.0892 - accuracy: 0.6139 - val_loss: 0.9352 - val_accuracy: 0.6693
# Epoch 3/5
# 49856/50000 [============================>.] - ETA: 0s - loss: 0.9426 - accuracy: 0.6668WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.9425 - accuracy: 0.6669 - val_loss: 0.8255 - val_accuracy: 0.7122
# Epoch 4/5
# 49824/50000 [============================>.] - ETA: 0s - loss: 0.8494 - accuracy: 0.7004WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 186us/sample - loss: 0.8493 - accuracy: 0.7004 - val_loss: 0.7614 - val_accuracy: 0.7358
# Epoch 5/5
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.7932 - accuracy: 0.7208WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.7931 - accuracy: 0.7208 - val_loss: 0.7481 - val_accuracy: 0.7419

# %%
# again training for 10 more epochs 
model.fit(x_train,y_train,          
          validation_data=(x_test,y_test),
          epochs=50,
          batch_size=32, callbacks=[mckpt],workers=4)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 49696/50000 [============================>.] - ETA: 0s - loss: 0.5282 - accuracy: 0.8138WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 190us/sample - loss: 0.5283 - accuracy: 0.8138 - val_loss: 0.6399 - val_accuracy: 0.7859
# Epoch 2/50
# 49728/50000 [============================>.] - ETA: 0s - loss: 0.5142 - accuracy: 0.8200WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 187us/sample - loss: 0.5140 - accuracy: 0.8200 - val_loss: 0.6281 - val_accuracy: 0.7932
# Epoch 3/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.5107 - accuracy: 0.8212WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.5108 - accuracy: 0.8212 - val_loss: 0.6272 - val_accuracy: 0.7923
# Epoch 4/50
# 49856/50000 [============================>.] - ETA: 0s - loss: 0.4995 - accuracy: 0.8255WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 186us/sample - loss: 0.4997 - accuracy: 0.8255 - val_loss: 0.6496 - val_accuracy: 0.7906
# Epoch 5/50
# 49760/50000 [============================>.] - ETA: 0s - loss: 0.4888 - accuracy: 0.8273WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.4889 - accuracy: 0.8272 - val_loss: 0.6635 - val_accuracy: 0.7828
# Epoch 6/50
# 49792/50000 [============================>.] - ETA: 0s - loss: 0.4827 - accuracy: 0.8319WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 187us/sample - loss: 0.4828 - accuracy: 0.8319 - val_loss: 0.6469 - val_accuracy: 0.7909
# Epoch 7/50
# 49760/50000 [============================>.] - ETA: 0s - loss: 0.4745 - accuracy: 0.8327WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.4757 - accuracy: 0.8324 - val_loss: 0.6686 - val_accuracy: 0.7848
# Epoch 8/50
# 49888/50000 [============================>.] - ETA: 0s - loss: 0.4683 - accuracy: 0.8361WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 188us/sample - loss: 0.4680 - accuracy: 0.8362 - val_loss: 0.6409 - val_accuracy: 0.7908
# Epoch 9/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.4547 - accuracy: 0.8413WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 186us/sample - loss: 0.4547 - accuracy: 0.8412 - val_loss: 0.6489 - val_accuracy: 0.7903
# Epoch 10/50
# 49952/50000 [============================>.] - ETA: 0s - loss: 0.4526 - accuracy: 0.8410WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 183us/sample - loss: 0.4526 - accuracy: 0.8410 - val_loss: 0.6472 - val_accuracy: 0.7947
# Epoch 11/50
# 49888/50000 [============================>.] - ETA: 0s - loss: 0.4426 - accuracy: 0.8427WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 186us/sample - loss: 0.4427 - accuracy: 0.8427 - val_loss: 0.6608 - val_accuracy: 0.7895
# Epoch 12/50
# 49856/50000 [============================>.] - ETA: 0s - loss: 0.4431 - accuracy: 0.8464WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.4431 - accuracy: 0.8465 - val_loss: 0.6390 - val_accuracy: 0.7952
# Epoch 13/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.4332 - accuracy: 0.8483WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.4332 - accuracy: 0.8483 - val_loss: 0.6499 - val_accuracy: 0.7985
# Epoch 14/50
# 49696/50000 [============================>.] - ETA: 0s - loss: 0.4280 - accuracy: 0.8503WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.4283 - accuracy: 0.8502 - val_loss: 0.6513 - val_accuracy: 0.7939
# Epoch 15/50
# 49792/50000 [============================>.] - ETA: 0s - loss: 0.4231 - accuracy: 0.8518WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 186us/sample - loss: 0.4235 - accuracy: 0.8516 - val_loss: 0.6336 - val_accuracy: 0.8011
# Epoch 16/50
# 49856/50000 [============================>.] - ETA: 0s - loss: 0.4184 - accuracy: 0.8534WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.4185 - accuracy: 0.8532 - val_loss: 0.6643 - val_accuracy: 0.7990
# Epoch 17/50
# 49888/50000 [============================>.] - ETA: 0s - loss: 0.4202 - accuracy: 0.8538WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.4204 - accuracy: 0.8537 - val_loss: 0.6565 - val_accuracy: 0.7934
# Epoch 18/50
# 49792/50000 [============================>.] - ETA: 0s - loss: 0.4144 - accuracy: 0.8540WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 186us/sample - loss: 0.4145 - accuracy: 0.8540 - val_loss: 0.6886 - val_accuracy: 0.7965
# Epoch 19/50
# 49792/50000 [============================>.] - ETA: 0s - loss: 0.4024 - accuracy: 0.8587WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 186us/sample - loss: 0.4022 - accuracy: 0.8589 - val_loss: 0.6709 - val_accuracy: 0.7934
# Epoch 20/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.4065 - accuracy: 0.8580WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 184us/sample - loss: 0.4065 - accuracy: 0.8579 - val_loss: 0.6543 - val_accuracy: 0.7983
# Epoch 21/50
# 49728/50000 [============================>.] - ETA: 0s - loss: 0.3955 - accuracy: 0.8620WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 186us/sample - loss: 0.3957 - accuracy: 0.8620 - val_loss: 0.6791 - val_accuracy: 0.7897
# Epoch 22/50
# 49760/50000 [============================>.] - ETA: 0s - loss: 0.3994 - accuracy: 0.8628WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 184us/sample - loss: 0.3994 - accuracy: 0.8628 - val_loss: 0.6799 - val_accuracy: 0.7956
# Epoch 23/50
# 49920/50000 [============================>.] - ETA: 0s - loss: 0.4014 - accuracy: 0.8601WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 184us/sample - loss: 0.4018 - accuracy: 0.8599 - val_loss: 0.6870 - val_accuracy: 0.7902
# Epoch 24/50
# 49760/50000 [============================>.] - ETA: 0s - loss: 0.3957 - accuracy: 0.8621WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 186us/sample - loss: 0.3959 - accuracy: 0.8620 - val_loss: 0.6406 - val_accuracy: 0.8006
# Epoch 25/50
# 49952/50000 [============================>.] - ETA: 0s - loss: 0.3890 - accuracy: 0.8645WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 184us/sample - loss: 0.3890 - accuracy: 0.8645 - val_loss: 0.6747 - val_accuracy: 0.7961
# Epoch 26/50
# 49728/50000 [============================>.] - ETA: 0s - loss: 0.3883 - accuracy: 0.8647WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.3886 - accuracy: 0.8646 - val_loss: 0.6817 - val_accuracy: 0.7935
# Epoch 27/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.3761 - accuracy: 0.8694WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 186us/sample - loss: 0.3760 - accuracy: 0.8694 - val_loss: 0.7148 - val_accuracy: 0.7959
# Epoch 28/50
# 49952/50000 [============================>.] - ETA: 0s - loss: 0.3827 - accuracy: 0.8680WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.3828 - accuracy: 0.8679 - val_loss: 0.6525 - val_accuracy: 0.8064
# Epoch 29/50
# 49792/50000 [============================>.] - ETA: 0s - loss: 0.3795 - accuracy: 0.8685WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 184us/sample - loss: 0.3793 - accuracy: 0.8686 - val_loss: 0.6690 - val_accuracy: 0.7992
# Epoch 30/50
# 49728/50000 [============================>.] - ETA: 0s - loss: 0.3665 - accuracy: 0.8723WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.3661 - accuracy: 0.8724 - val_loss: 0.6647 - val_accuracy: 0.8073
# Epoch 31/50
# 49760/50000 [============================>.] - ETA: 0s - loss: 0.3777 - accuracy: 0.8702WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 10s 192us/sample - loss: 0.3781 - accuracy: 0.8701 - val_loss: 0.7149 - val_accuracy: 0.8036
# Epoch 32/50
# 49824/50000 [============================>.] - ETA: 0s - loss: 0.3752 - accuracy: 0.8717WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.3755 - accuracy: 0.8716 - val_loss: 0.6917 - val_accuracy: 0.8034
# Epoch 33/50
# 49792/50000 [============================>.] - ETA: 0s - loss: 0.3624 - accuracy: 0.8746WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 186us/sample - loss: 0.3625 - accuracy: 0.8746 - val_loss: 0.6738 - val_accuracy: 0.8049
# Epoch 34/50
# 49792/50000 [============================>.] - ETA: 0s - loss: 0.3736 - accuracy: 0.8730WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 186us/sample - loss: 0.3738 - accuracy: 0.8730 - val_loss: 0.6719 - val_accuracy: 0.8058
# Epoch 35/50
# 49888/50000 [============================>.] - ETA: 0s - loss: 0.3675 - accuracy: 0.8726WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 184us/sample - loss: 0.3673 - accuracy: 0.8727 - val_loss: 0.6785 - val_accuracy: 0.7954
# Epoch 36/50
# 49760/50000 [============================>.] - ETA: 0s - loss: 0.3564 - accuracy: 0.8766WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.3567 - accuracy: 0.8764 - val_loss: 0.6910 - val_accuracy: 0.7996
# Epoch 37/50
# 49696/50000 [============================>.] - ETA: 0s - loss: 0.3656 - accuracy: 0.8747WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.3656 - accuracy: 0.8747 - val_loss: 0.6881 - val_accuracy: 0.7960
# Epoch 38/50
# 49824/50000 [============================>.] - ETA: 0s - loss: 0.3542 - accuracy: 0.8788WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 182us/sample - loss: 0.3541 - accuracy: 0.8788 - val_loss: 0.6929 - val_accuracy: 0.8021
# Epoch 39/50
# 49856/50000 [============================>.] - ETA: 0s - loss: 0.3604 - accuracy: 0.8765WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 187us/sample - loss: 0.3605 - accuracy: 0.8765 - val_loss: 0.7009 - val_accuracy: 0.8028
# Epoch 40/50
# 49824/50000 [============================>.] - ETA: 0s - loss: 0.3557 - accuracy: 0.8779WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 186us/sample - loss: 0.3559 - accuracy: 0.8779 - val_loss: 0.6672 - val_accuracy: 0.8006
# Epoch 41/50
# 49792/50000 [============================>.] - ETA: 0s - loss: 0.3515 - accuracy: 0.8802WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 183us/sample - loss: 0.3515 - accuracy: 0.8802 - val_loss: 0.6787 - val_accuracy: 0.8032
# Epoch 42/50
# 49824/50000 [============================>.] - ETA: 0s - loss: 0.3544 - accuracy: 0.8784WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 182us/sample - loss: 0.3541 - accuracy: 0.8784 - val_loss: 0.7148 - val_accuracy: 0.7943
# Epoch 43/50
# 49824/50000 [============================>.] - ETA: 0s - loss: 0.3495 - accuracy: 0.8800WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 183us/sample - loss: 0.3494 - accuracy: 0.8800 - val_loss: 0.6747 - val_accuracy: 0.8015
# Epoch 44/50
# 49888/50000 [============================>.] - ETA: 0s - loss: 0.3476 - accuracy: 0.8812WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 184us/sample - loss: 0.3475 - accuracy: 0.8813 - val_loss: 0.7377 - val_accuracy: 0.7952
# Epoch 45/50
# 49888/50000 [============================>.] - ETA: 0s - loss: 0.3497 - accuracy: 0.8803WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 182us/sample - loss: 0.3498 - accuracy: 0.8801 - val_loss: 0.6769 - val_accuracy: 0.7997
# Epoch 46/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.3433 - accuracy: 0.8815WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 186us/sample - loss: 0.3433 - accuracy: 0.8815 - val_loss: 0.6980 - val_accuracy: 0.8008
# Epoch 47/50
# 49888/50000 [============================>.] - ETA: 0s - loss: 0.3439 - accuracy: 0.8824WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.3440 - accuracy: 0.8823 - val_loss: 0.6909 - val_accuracy: 0.7995
# Epoch 48/50
# 49760/50000 [============================>.] - ETA: 0s - loss: 0.3439 - accuracy: 0.8827WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 183us/sample - loss: 0.3435 - accuracy: 0.8828 - val_loss: 0.6918 - val_accuracy: 0.8018
# Epoch 49/50
# 49984/50000 [============================>.] - ETA: 0s - loss: 0.3314 - accuracy: 0.8849WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 182us/sample - loss: 0.3315 - accuracy: 0.8849 - val_loss: 0.7024 - val_accuracy: 0.8006
# Epoch 50/50
# 49856/50000 [============================>.] - ETA: 0s - loss: 0.3438 - accuracy: 0.8826WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 50000/50000 [==============================] - 9s 183us/sample - loss: 0.3435 - accuracy: 0.8827 - val_loss: 0.7091 - val_accuracy: 0.7985

# %% [markdown]
# Q7. Import packages required for VGG16
#
# *   `tf.keras.application`
# > VGG16, preprocess_input, decode_predictions
# *   `tf.keras.preprocessing`
# > load_img, img_to_array

# %%
from tensorflow.keras.applications.vgg16 import VGG16,preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import array_to_img,load_img,img_to_array

# %% [markdown]
# Q8. Load image
#
#
# *   Mount Google Drive
# *   Navigate to image location (use `os`)
# *   Load image and assign a variable (use `load_img`)

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# load an image from file
image = load_img('/content/drive/My Drive/Resedency/31jan2020/LabInternalResidency8/images/humming_bird.jpg', target_size=(224, 224))

# %%
# using loop opreation for fectching 4 images and applying pre-processing 
images = []
for img1 in os.listdir(r'/content/drive/My Drive/Resedency/31jan2020/LabInternalResidency8/images/'):
    print(img1)
    img2 = load_img(r'/content/drive/My Drive/Resedency/31jan2020/LabInternalResidency8/images' +'/'+ img1, target_size=(224, 224))
    #print(plt.imshow(img2))
    img2 = img_to_array(img2)
    img2 = img2.reshape((1, img2.shape[0], img2.shape[1], img2.shape[2]))
    img2 = preprocess_input(img2)
    images.append(img2)
images = np.vstack(images)
# Out:
# butterfly.jpg
# humming_bird.jpg
# train.jpg
# mug.jpg

# %%
img = os.chdir(path)
img_get = os.getcwd()
# !ls
# Out:
# butterfly.jpg  humming_bird.jpg  mug.jpg  train.jpg

# %% [markdown]
# Q9. Preprocess the image
#
#
# *   Convert image into array (use `img_to_array`)
# *   Check shape of image
# *   Reshape image into 4 dimensional format (use `reshape`)
# *   Prepare the image for VGG16 (Use `preprocess_input()`)

# %%
# convert the image pixels to a numpy array
image_array = img_to_array(image)
print ('shape of image_array',image_array.shape)
# Out:
# shape of image_array (224, 224, 3)

# %%
# reshape data for the model
image_array = image_array.reshape((1, image_array.shape[0], image_array.shape[1], image_array.shape[2]))

# %%
print ('shape of image_array',image_array.shape)
# Out:
# shape of image_array (1, 224, 224, 3)

# %%
# prepare the image for the VGG model
image_vgg16 = preprocess_input(image_array)

# %%
# load the model
model = VGG16()

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Q10. Predict the Class of image
#
#
# *   Use `predict()` to calculate probabilities (Assign a variable)
# *   Convert the probabilities to class labels (Use `decode_predictions`)(Assign a variable)
# *   Print the classification results
#
#
# > Use
# >*  label = label[0][0]
# >*   print('%s (%.2f%%)' % (label[1], label[2]*100))
# >*(where label is variable assigned for `decode_predictions` )

# %%
y_perd = model.predict(image_vgg16)

# %%
y_perd_4 = model.predict(images) # loading pre-process images from loop

# %%
# convert the probabilities to class labels
label = decode_predictions(y_perd)

# %%
# convert the probabilities to class labels
label_4 = decode_predictions(y_perd_4, top=1)

# %%
label_4
# Out:
# [[('n02279972', 'monarch', 0.99720985)],
#  [('n01833805', 'hummingbird', 0.3652913)],
#  [('n03393912', 'freight_car', 0.34337312)],
#  [('n03063599', 'coffee_mug', 0.7589643)]]

# %%
label_4[2][0]
# Out:
# ('n03393912', 'freight_car', 0.34337312)

# %%
# retrieve the most likely result, e.g. highest probability
label = label[0][0]
label
# Out:
# 'n'

# %%
# Storing top results of vgg16 prediction in printable list 
printable = []
for i in range(len(label_4)):
  label_i = label_4[i][0]
  print (label_i)
  printable.append(label_i)
# Out:
# ('n02279972', 'monarch', 0.99720985)
# ('n01833805', 'hummingbird', 0.3652913)
# ('n03393912', 'freight_car', 0.34337312)
# ('n03063599', 'coffee_mug', 0.7589643)

# %%
# print the classification
print('%s (%.2f%%)' % (label[1], label[2]*100))
# Out:
# hummingbird (36.53%)

# %%
printable[0]
# Out:
# ('n02279972', 'monarch', 0.99720985)

# %%
# printing the all the answer from printable which are predicted by VGG16
for i in printable:
  print('%s (%.2f%%)' % (i[1], i[2]*100))
# Out:
# monarch (99.72%)
# hummingbird (36.53%)
# freight_car (34.34%)
# coffee_mug (75.90%)

# %% [markdown]
# #NLP

# %% [markdown]
# ## Question 1

# %% [markdown]
# Read file 'tweets.csv'

# %%
import pandas as pd

# %%
tweets = pd.read_csv('/content/drive/My Drive/Resedency/31jan2020/LabInternalResidency8/tweets.csv',encoding = 'mac_roman')

# %%
print ('shape of tweets',tweets.shape)
# Out:
# shape of tweets (9093, 3)

# %% [markdown]
# **Drop null values**
#
# *   Drop all the rows with null values

# %%
df = tweets.dropna()

# %%
print ('shape of df',tw.shape)
# Out:
# shape of df (3291, 3)

# %% [markdown]
# **Print the dataframe**
# *   print initial 5 rows of the data

# %%
df.head()
# Out:
#                                           tweet_text  ... is_there_an_emotion_directed_at_a_brand_or_product
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs twe...  ...                                   Negative emotion
# 1  @jessedee Know about @fludapp ? Awesome iPad/i...  ...                                   Positive emotion
# 2  @swonderlin Can not wait for #iPad 2 also. The...  ...                                   Positive emotion
# 3  @sxsw I hope this year's festival isn't as cra...  ...                                   Negative emotion
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa M...  ...                                   Positive emotion
#
# [5 rows x 3 columns]

# %% [markdown]
# ##Question 2

# %% [markdown]
# **Preprocess data**
#
#
# *   convert all text to lowercase - use .lower()
# *   select only numbers, alphabets, and #+_ from text - use re.sub()
# *   strip all the text - use .strip() [To remove extra spaces]

# %%
import re

# %%
df['tweet_text'] = df['tweet_text'].apply(lambda s: re.sub('[^0-9a-z #+_]','',s))
df['tweet_text'] = df['tweet_text'].apply(lambda s: s.lower())
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['tweet_text'] = df['tweet_text'].apply(lambda s: s.strip())
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#                                           tweet_text  ... is_there_an_emotion_directed_at_a_brand_or_product
# 0  wesley83  have a 3 ihone fter 3 hrs tweeting a...  ...                                   Negative emotion
# 1  jessedee now about fludapp  wesome iadihone ap...  ...                                   Positive emotion
# 2  swonderlin an not wait for #iad 2 also hey sho...  ...                                   Positive emotion
# 3  sxsw  hope this years festival isnt as crashy ...  ...                                   Negative emotion
# 4  sxtxstate great stuff on ri # arissa ayer oogl...  ...                                   Positive emotion
#
# [5 rows x 3 columns]

# %% [markdown]
# ## Question 3

# %%
df['is_there_an_emotion_directed_at_a_brand_or_product'].unique()
# Out:
# array(['Negative emotion', 'Positive emotion',
#        'No emotion toward brand or product', "I can't tell"], dtype=object)

# %%
df['is_there_an_emotion_directed_at_a_brand_or_product'].value_counts()
# Out:
# Positive emotion                      2672
# Negative emotion                       519
# No emotion toward brand or product      91
# I can't tell                             9
# Name: is_there_an_emotion_directed_at_a_brand_or_product, dtype: int64

# %% [markdown]
# **Preprocess data**
#
#
# *   in column "is_there_an_emotion_directed_at_a_brand_or_product"
# select only those rows where value equal to "positive emotion" or "negative emotion"
# *   find the value counts of "positive emotion" and "negative emotion"

# %%
df = df[(df['is_there_an_emotion_directed_at_a_brand_or_product'] == 'Negative emotion') | (df['is_there_an_emotion_directed_at_a_brand_or_product'] == 'Positive emotion')]

# %%
df.head()
# Out:
#                                           tweet_text  ... is_there_an_emotion_directed_at_a_brand_or_product
# 0  wesley83  have a 3 ihone fter 3 hrs tweeting a...  ...                                   Negative emotion
# 1  jessedee now about fludapp  wesome iadihone ap...  ...                                   Positive emotion
# 2  swonderlin an not wait for #iad 2 also hey sho...  ...                                   Positive emotion
# 3  sxsw  hope this years festival isnt as crashy ...  ...                                   Negative emotion
# 4  sxtxstate great stuff on ri # arissa ayer oogl...  ...                                   Positive emotion
#
# [5 rows x 3 columns]

# %% [markdown]
# ##Question 4

# %% [markdown]
# ### Encode labels
# - in column "is_there_an_emotion_directed_at_a_brand_or_product"
#     - change "positive emotion" to 1
#     - change "negative emotion" to 0
# - use map function to replace values

# %%
df['label']= df.is_there_an_emotion_directed_at_a_brand_or_product.map({'Negative emotion': 0, 'Positive emotion':1})

# %%
df.head()
# Out:
#                                           tweet_text  ... label
# 0  wesley83  have a 3 ihone fter 3 hrs tweeting a...  ...     0
# 1  jessedee now about fludapp  wesome iadihone ap...  ...     1
# 2  swonderlin an not wait for #iad 2 also hey sho...  ...     1
# 3  sxsw  hope this years festival isnt as crashy ...  ...     0
# 4  sxtxstate great stuff on ri # arissa ayer oogl...  ...     1
#
# [5 rows x 4 columns]

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Get feature and label
# - get column "tweet_text" as feature
# - get column "is_there_an_emotion_directed_at_a_brand_or_product" as label

# %%
x = df.tweet_text

# %%
y=df.is_there_an_emotion_directed_at_a_brand_or_product

# %%
print('shape of x',x.shape)
print('shape of y',y.shape)
# Out:
# shape of x (3191,)
# shape of y (3191,)

# %% [markdown]
# ### Create train and test data
# - use train_test_split to get train and test set
# - set a random_state
# - test_size: 0.25

# %%
import pandas as pd
import numpy as np
import scipy as sp
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
# %matplotlib inline

# %%
# split the new DataFrame into training and testing sets [Default test size = 25%]
X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=1,test_size = 0.25)

# %%
X_train.shape
# Out:
# (2393,)

# %%
X_test.shape
# Out:
# (798,)

# %% [markdown]
# ## Question 6
#
# ### Vectorize data
# - create document-term matrix
# - use CountVectorizer()
#     - ngram_range: (1, 2)
#     - stop_words: 'english'
#     - min_df: 2
# - do fit_transform on X_train
# - do transform on X_test

# %%
# use CountVectorizer to create document-term matrices from X_train and X_test
vect = CountVectorizer(ngram_range=(1,2),stop_words='english',min_df=2)
X_train_dtm = vect.fit_transform(X_train)
X_test_dtm = vect.transform(X_test)

# %% [markdown]
# ## Question 7
#
# ### Select classifier logistic regression
# - use logistic regression for predicting sentiment of the given tweet
# - initialize classifier

# %%
# use logistic regression with text column only
logreg = LogisticRegression(C=1e9)

# %% [markdown]
# ### Fit the classifer
# - fit logistic regression classifier

# %%
logreg.fit(X_train_dtm, y_train)
# Out:
# LogisticRegression(C=1000000000.0, class_weight=None, dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# ## Question 8
#
# ### Select classifier naive bayes
# - use naive bayes for predicting sentiment of the given tweet
# - initialize classifier
# - use MultinomialNB

# %%
 nb = MultinomialNB()

# %% [markdown]
# ### Fit the classifer
# - fit naive bayes classifier

# %%
nb.fit(X_train_dtm, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# ## Question 9
#
# ### Make predictions on logistic regression
# - use your trained logistic regression model to make predictions on X_test

# %%
y_pred_class_l = logreg.predict(X_test_dtm)

# %% [markdown]
# ### Make predictions on naive bayes
# - use your trained naive bayes model to make predictions on X_test
# - use a different variable name to store predictions so that they are kept separately

# %%
y_pred_class_nb = nb.predict(X_test_dtm)

# %% [markdown]
# ## Question 10
#
# ### Calculate accuracy of logistic regression
# - check accuracy of logistic regression classifer
# - use sklearn.metrics.accuracy_score

# %%
print(metrics.accuracy_score(y_test, y_pred_class_l))
# Out:
# 0.8395989974937343

# %% [markdown]
# ### Calculate accuracy of naive bayes
# - check accuracy of naive bayes classifer
# - use sklearn.metrics.accuracy_score

# %%
print('Accuracy: ', metrics.accuracy_score(y_test, y_pred_class_nb))
# Out:
# Accuracy:  0.8583959899749374
